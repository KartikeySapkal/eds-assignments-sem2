# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
x=[1,2,3,4]
y=[30,20,70,40]
plt.plot(x,y,color='red',marker='*')
plt.axis([0, 6, 0, 90])
plt.title("Result")
plt.xlabel("Roll No.")
plt.ylabel("Marks")
plt.grid()
plt.show()

# %%
x=np.linspace(0,10,100)

# %%
plt.plot(x,np.sin(x))
plt.grid()

# %%
placement= pd.read_csv("/Users/kartikeysapkal/Documents/Python/CSV's/PlacementData.csv")
lstyr = pd.read_csv("/Users/kartikeysapkal/Downloads/Placed Students List-2021-2022 Batch(1).xlsx - Placed Students List-2022 Batch.csv")
lstyr
# Out:
#      S.No          NAME OF STUDENT      BRANCH              RECRUITERS
# 0       1    Kaustubh kishan patil    Computer           Eq technologic  \
# 1       2   Prachi sakhahari patil    Computer  Zs associates pvt. Ltd.
# 2       3    Shubham kishor sapkal    Computer  Zs associates pvt. Ltd.
# 3       4   Sushant madhukar patil    Computer  Zs associates pvt. Ltd.
# 4       5  Tejas pravin kshirsagar    Computer  Zs associates pvt. Ltd.
# ..    ...                      ...         ...                      ...
# 555   556    Pankaj Vitthal Mhaske   Chemical             JSW Steel Ltd
# 556   557  Nilesh Babasaheb Darade       Civil                PPS Group
# 557   558  Prajakta  Sanjay Pehere       Civil                PPS Group
# 558   559  Mangesh Narahari Pawar   Mechanical   Sanghvi movers limited
# 559   560             Paras kapoor  Mechanical   Sanghvi movers limited
#
#      PACKAGEINLAKH
# 0            10.00
# 1             9.50
# 2             9.50
# 3             9.50
# ...

# %%
placement
# Out:
#      S.NO              NAMEOFSTUDENT       BRANCH                RECRUITERS
# 0       1         Sameer Manik Patil           IT  Veritas Technologies LLC  \
# 1       2       Shruti Deepak Dhumne     Computer  Veritas Technologies LLC
# 2       3      Prajyoti Maruti Patil           IT               Avaya India
# 3       4         Rajesh Sarat Sahoo     Computer               Avaya India
# 4       5      Yash Rameshwar Charpe     Computer                       BMC
# ..    ...                        ...          ...                       ...
# 527   528    Arjun Rajusing Pardeshi  Mechanical                   LG india
# 528   529   Aditya Vishwasrao Mukund         E&TC                  LG india
# 529   530      Indrajit Kishor Pawar         E&TC                  LG india
# 530   531  Shubham Dharmraj Chougule  Mechanical                   LG india
# 531   532   Sneha Madhavrao Athawale  Mechanical                   LG india
#
#      PACKAGEINLAKH
# 0            15.97
# ...

# %%
plt.figure(figsize=(12,5))
plt.plot(placement.PACKAGEINLAKH,label='2022',color='Orange',marker='D')
plt.plot(lstyr.PACKAGEINLAKH,label="2020",color='Blue',marker='o')
plt.legend()

plt.axis([0,560,0,30])
plt.grid()
plt.show()

# %%
plt.hist(placement['PACKAGEINLAKH'],color='r',label='placements')
plt.xlabel('No of students')
plt.ylabel('Package in Lakhs')
plt.ylim(0, 250)
plt.xlim(0, 25)
plt.legend()
plt.show()

# %%
plt.bar(placement['PACKAGEINLAKH'],placement['S.NO'],color='blue',label='Placement', align='edge', width=0.3)
# Out:
# <BarContainer object of 532 artists>
