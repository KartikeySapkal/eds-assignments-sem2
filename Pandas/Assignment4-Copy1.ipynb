# %%
import pandas as pd
import numpy as np

# %%
f1 = open("/Users/kartikeysapkal/Documents/Python/CSV's/grainsales.csv","r")

data = pd.read_csv(f1)

# %%
data

df = pd.DataFrame(data)

maindata = df #im creating this variable to reset my dataframe

# %%
df['Sales'].describe()
# Out:
# count    2.700000e+01
# mean     2.685185e+06
# std      1.249216e+06
# min      1.000000e+06
# 25%      1.500000e+06
# 50%      3.000000e+06
# 75%      3.750000e+06
# max      4.500000e+06
# Name: Sales, dtype: float64

# %%
df=df.groupby('Months').sum()

# %%
df=df.sort_values(by=['Sales'],ascending=False)
df
# Out:
#                                            GrainName
# Months
# JULY                            WheatWheatWheatWheat  \
# JUNE    Brown rice Brown rice Brown rice Brown rice
# AUG                                     CornCornCorn
# MAY                                  SoojiSoojiSooji
# FEB                             BajraBajraBajraBajra
# APRIL                                   Sattu Sattu
# JAN                             RagiRagiRagiRagiRagi
# MARCH                                       OatsOats
#
#                                                     State
# Months
# JULY         West BengolWest BengolWest BengolWest Bengol  \
# JUNE                 TelanganaTelanganaTelanganaTelangana
# AUG                                                UPUPUP
# MAY                        Tamil NaduTamil NaduTamil Nadu
# FEB                              PanjabPanjabPanjabPanjab
# APRIL                                      GujaratGujarat
# JAN     MaharashtraMaharashtraMaharashtraMaharashtraMa...
# MARCH                                    HariyanaHariyana
#
#                                         City   Year     Sales
# Months
# JULY        AsansoleAsansoleAsansoleAsansole   8092  16000000
# JUNE    HyderabadHyderabadHyderabadHyderabad   8092  14000000
# AUG                       KanpurKanpurKanpur   6069  13500000
# MAY                    MaduraiMaduraiMadurai   6069   9000000
# FEB         AmritsarAmritsarAmritsarAmritsar   8092   6000000
# APRIL                             SuratSurat   4046   5000000
# JAN           NagpurNagpurNagpurNagpurNagpur  10115   5000000
# MARCH                       GurugramGurugram   4046   4000000

# %%
df.head(1)
# Out:
#                    GrainName                                         State
# Months
# JULY    WheatWheatWheatWheat  West BengolWest BengolWest BengolWest Bengol  \
#
#                                     City  Year     Sales
# Months
# JULY    AsansoleAsansoleAsansoleAsansole  8092  16000000

# %%
print("Best Month for Sales: July")
# Out:
# Best Month for Sales: July

# %%
print("Revenue Earned was: 16000000")
# Out:
# Revenue Earned was: 16000000

# %%
maindata
# Out:
#       GrainName        State       City Months  Year    Sales
# 0          Ragi  Maharashtra     Nagpur    JAN  2023  1000000
# 1         Bajra       Panjab   Amritsar    FEB  2023  1500000
# 2          Ragi  Maharashtra     Nagpur    JAN  2023  1000000
# 3         Bajra       Panjab   Amritsar    FEB  2023  1500000
# 4          Ragi  Maharashtra     Nagpur    JAN  2023  1000000
# 5         Bajra       Panjab   Amritsar    FEB  2023  1500000
# 6          Oats     Hariyana   Gurugram  MARCH  2023  2000000
# 7        Sattu       Gujarat      Surat  APRIL  2023  2500000
# 8         Sooji   Tamil Nadu    Madurai    MAY  2023  3000000
# 9   Brown rice     Telangana  Hyderabad   JUNE  2023  3500000
# 10        Wheat  West Bengol   Asansole   JULY  2023  4000000
# 11         Corn           UP     Kanpur    AUG  2023  4500000
# 12         Ragi  Maharashtra     Nagpur    JAN  2023  1000000
# 13        Bajra       Panjab   Amritsar    FEB  2023  1500000
# 14         Oats     Hariyana   Gurugram  MARCH  2023  2000000
# 15       Sattu       Gujarat      Surat  APRIL  2023  2500000
# 16        Sooji   Tamil Nadu    Madurai    MAY  2023  3000000
# 17  Brown rice     Telangana  Hyderabad   JUNE  2023  3500000
# 18        Wheat  West Bengol   Asansole   JULY  2023  4000000
# 19         Corn           UP     Kanpur    AUG  2023  4500000
# 20        Sooji   Tamil Nadu    Madurai    MAY  2023  3000000
# 21  Brown rice     Telangana  Hyderabad   JUNE  2023  3500000
# 22        Wheat  West Bengol   Asansole   JULY  2023  4000000
# 23         Corn           UP     Kanpur    AUG  2023  4500000
# 24         Ragi  Maharashtra     Nagpur    JAN  2023  1000000
# 25  Brown rice     Telangana  Hyderabad   JUNE  2023  3500000
# 26        Wheat  West Bengol   Asansole   JULY  2023  4000000

# %%
df = maindata

# %%
df = df.groupby("GrainName").sum()

# %%
df = df.sort_values(by=["Sales"],ascending = False)

# %%
df
# Out:
#                                                          State
# GrainName
# Wheat             West BengolWest BengolWest BengolWest Bengol  \
# Brown rice                TelanganaTelanganaTelanganaTelangana
# Corn                                                    UPUPUP
# Sooji                           Tamil NaduTamil NaduTamil Nadu
# Bajra                                 PanjabPanjabPanjabPanjab
# Ragi         MaharashtraMaharashtraMaharashtraMaharashtraMa...
# Sattu                                           GujaratGujarat
# Oats                                          HariyanaHariyana
#
#                                              City            Months   Year
# GrainName
# Wheat            AsansoleAsansoleAsansoleAsansole  JULYJULYJULYJULY   8092  \
# Brown rice   HyderabadHyderabadHyderabadHyderabad  JUNEJUNEJUNEJUNE   8092
# Corn                           KanpurKanpurKanpur         AUGAUGAUG   6069
# Sooji                       MaduraiMaduraiMadurai         MAYMAYMAY   6069
# Bajra            AmritsarAmritsarAmritsarAmritsar      FEBFEBFEBFEB   8092
# Ragi               NagpurNagpurNagpurNagpurNagpur   JANJANJANJANJAN  10115
# Sattu                                  SuratSurat        APRILAPRIL   4046
# Oats                             GurugramGurugram        MARCHMARCH   4046
#
#                 Sales
# GrainName
# Wheat        16000000
# Brown rice   14000000
# Corn         13500000
# Sooji         9000000
# Bajra         6000000
# Ragi          5000000
# Sattu         5000000
# Oats          4000000

# %%
df.head(1)
# Out:
#                                                   State
# GrainName
# Wheat      West BengolWest BengolWest BengolWest Bengol  \
#
#                                        City            Months  Year     Sales
# GrainName
# Wheat      AsansoleAsansoleAsansoleAsansole  JULYJULYJULYJULY  8092  16000000

# %%
print("Most Sold Grain is: Wheat")
print("The Best Month for sales is July and this product has occured in July so this is most sold product with highest sales")
# Out:
# Most Sold Grain is: Wheat
# The Best Month for sales is July and this product has occured in July so this is most sold product with highest sales

# %%
df = maindata

# %%
df= df.groupby("City").sum()

# %%
df = df.sort_values(by = ['Sales'],ascending= False)
df.head(1)
# Out:
#                      GrainName                                         State
# City
# Asansole  WheatWheatWheatWheat  West BengolWest BengolWest BengolWest Bengol  \
#
#                     Months  Year     Sales
# City
# Asansole  JULYJULYJULYJULY  8092  16000000

# %%
print("'Asansole' Has sold highest no. of products")
# Out:
# 'Asansole' Has sold highest no. of products

# %%
df = maindata #dataframe is reseted

# %%
df = df.groupby('State').sum()

# %%
df
# Out:
#                                                 GrainName
# State
# Gujarat                                      Sattu Sattu   \
# Hariyana                                         OatsOats
# Maharashtra                          RagiRagiRagiRagiRagi
# Panjab                               BajraBajraBajraBajra
# Tamil Nadu                                SoojiSoojiSooji
# Telangana    Brown rice Brown rice Brown rice Brown rice
# UP                                           CornCornCorn
# West Bengol                          WheatWheatWheatWheat
#
#                                              City            Months   Year
# State
# Gujarat                                SuratSurat        APRILAPRIL   4046  \
# Hariyana                         GurugramGurugram        MARCHMARCH   4046
# Maharashtra        NagpurNagpurNagpurNagpurNagpur   JANJANJANJANJAN  10115
# Panjab           AmritsarAmritsarAmritsarAmritsar      FEBFEBFEBFEB   8092
# Tamil Nadu                  MaduraiMaduraiMadurai         MAYMAYMAY   6069
# Telangana    HyderabadHyderabadHyderabadHyderabad  JUNEJUNEJUNEJUNE   8092
# UP                             KanpurKanpurKanpur         AUGAUGAUG   6069
# West Bengol      AsansoleAsansoleAsansoleAsansole  JULYJULYJULYJULY   8092
#
#                 Sales
# State
# Gujarat       5000000
# Hariyana      4000000
# Maharashtra   5000000
# Panjab        6000000
# Tamil Nadu    9000000
# Telangana    14000000
# UP           13500000
# West Bengol  16000000

# %%
df = df.sort_values(by = ['Sales'],ascending = False)

# %%
df
# Out:
#                                                 GrainName
# State
# West Bengol                          WheatWheatWheatWheat  \
# Telangana    Brown rice Brown rice Brown rice Brown rice
# UP                                           CornCornCorn
# Tamil Nadu                                SoojiSoojiSooji
# Panjab                               BajraBajraBajraBajra
# Gujarat                                      Sattu Sattu
# Maharashtra                          RagiRagiRagiRagiRagi
# Hariyana                                         OatsOats
#
#                                              City            Months   Year
# State
# West Bengol      AsansoleAsansoleAsansoleAsansole  JULYJULYJULYJULY   8092  \
# Telangana    HyderabadHyderabadHyderabadHyderabad  JUNEJUNEJUNEJUNE   8092
# UP                             KanpurKanpurKanpur         AUGAUGAUG   6069
# Tamil Nadu                  MaduraiMaduraiMadurai         MAYMAYMAY   6069
# Panjab           AmritsarAmritsarAmritsarAmritsar      FEBFEBFEBFEB   8092
# Gujarat                                SuratSurat        APRILAPRIL   4046
# Maharashtra        NagpurNagpurNagpurNagpurNagpur   JANJANJANJANJAN  10115
# Hariyana                         GurugramGurugram        MARCHMARCH   4046
#
#                 Sales
# State
# West Bengol  16000000
# Telangana    14000000
# UP           13500000
# Tamil Nadu    9000000
# Panjab        6000000
# Gujarat       5000000
# Maharashtra   5000000
# Hariyana      4000000

# %%
print("West Bengol has highest sales")
# Out:
# West Bengol has highest sales
